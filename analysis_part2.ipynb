# %%
import pandas as pd
import numpy as np
import drive
import sys
import csv
import glob
import os

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-5693ac7e-95c8-4387-8f91-7a546d373ea5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5693ac7e-95c8-4387-8f91-7a546d373ea5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from zipfile import ZipFile

# %%
with ZipFile('稼働データ.zip','r') as zipObj:
  zipObj.extractall()

# %%
path = os.getcwd()
files = os.listdir('C:\タスク\東洋精鋼\稼働データ')
files
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-14-18a2dfc4b4fb> in <module>
#       1 path = os.getcwd()
# ----> 2 files = os.listdir('C:\タスク\東洋精鋼\稼働データ')
#       3 files
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\タスク\\東洋精鋼\\稼働データ'

# %%
df = pd.DataFrame()

# %%
for f in uploaded:
    data = pd.read_excel(f, '22号機')
    df = df.append(data)

# %%
df
# Out:
#        ユーザーID  モデルID         モデル名  カメラID  カメラ名  カメラエリアID  クラスID     クラス名  \
# 0           2      1  Bobbin_v1.0      2  22号機         6      0       稼働
# 1           2      1  Bobbin_v1.0      2  22号機         6      0       稼働
# 2           2      1  Bobbin_v1.0      2  22号機         7      0       稼働
# 3           2      1  Bobbin_v1.0      2  22号機         9      0       稼働
# 4           2      1  Bobbin_v1.0      2  22号機        10      0       稼働
# ...       ...    ...          ...    ...   ...       ...    ...      ...
# 76145       2      1  Bobbin_v1.0      2  22号機        38    999  NO_DATA
# 76146       2      1  Bobbin_v1.0      2  22号機        39    999  NO_DATA
# 76147       2      1  Bobbin_v1.0      2  22号機        40      0       稼働
# 76148       2      1  Bobbin_v1.0      2  22号機        41    999  NO_DATA
# 76149       2      1  Bobbin_v1.0      2  22号機         7      0       稼働
#
#        精度スコア  作業者名  指示書名                 検出日時  経過時間
# ...

# %%
df2 = df.drop(df.iloc[:, 0:3],axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.8/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.8/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...
